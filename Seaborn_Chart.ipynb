# %%
import seaborn as sns
# %matplotlib inline
import matplotlib as plt
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
pd.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.get_dataset_names()
#
# AttributeError: module 'pandas' has no attribute 'get_dataset_names'

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=tips['total_bill'],bins=30)

# %%
sns.distplot(x= "total_bill", bins = 30, data = tip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.distplot(x= "total_bill", bins = 30, data = tip)
#
# NameError: name 'tip' is not defined

# %%
sns.displot(tips['total_bill'],kde=False) ## if want to remove the line, add (kde = Fals) after

# %%
sns.displot(tips['total_bill'],kde=False, bins=30)

# %%
sns.pairplot(tips)

# %%
sns.scatterplot(x ="total_bill", y = "tip", data = tips, hue = "smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x="total_bill", 
            y="tip", data=tips,
            kind="scatter", 
            col="smoker")  # this will make in 2 column. row=smoker or time will make in 2 row

# %%
sns.relplot(x="total_bill", 
            y="tip", data=tips,
            kind="scatter", 
            col="smoker",
            row="time")

# %%
sns.relplot(x="total_bill", 
            y="tip", data=tips,
            kind="scatter", 
            col="day",
            col_wrap=2)  # col_order=["sunday","monday".......]

# %%
sns.boxplot(x= 'day', y= 'total_bill', data  = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,
               x='sex',
               y='tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
from scipy.stats import bernoulli

# %%
import urllib
urllib.urlretrieve("https://lib.stat.cmu.edu/datasets/CPS_85_Wages")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 import urllib
# ----> 2 urllib.urlretrieve("https://lib.stat.cmu.edu/datasets/CPS_85_Wages")
#
# AttributeError: module 'urllib' has no attribute 'urlretrieve'

# %%
url = https://lib.stat.cmu.edu/datasets/CPS_85_Wages
pd.read_text(url)
# Out:
#   Cell In[5], line 1
#     url = https://lib.stat.cmu.edu/datasets/CPS_85_Wages
#                ^
# SyntaxError: invalid syntax
